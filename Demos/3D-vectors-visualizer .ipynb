# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot3Dvectors( listOfVectors ):

    # allocate the figure
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    # define the plotting environment
    limit = np.max( np.absolute(listOfVectors) )
    
    # set the limits
    ax.set_xlim(-limit, limit)
    ax.set_ylim(-limit, limit)
    ax.set_zlim(-limit, limit)
    
    # set the origin
    o  = [0, 0, 0]
    
    # plot each vector independently
    for vector in listOfVectors:
        ax.quiver( 0, 0, 0, vector[0], vector[1], vector[2] )
    
    # show the stuff
    plt.show()

# %%
A = np.array( [ [ 1, 0, 0 ],
                [ 2, 4, 0 ],
                [ 0, 3, 3 ] ] )

plot3Dvectors( A )

fig = plt.gcf()
fig.set_size_inches(18.5, 19.5)
